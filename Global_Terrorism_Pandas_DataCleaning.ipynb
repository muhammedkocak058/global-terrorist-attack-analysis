# %%
import pandas as pd

# %%
df = pd.read_csv(r'c:\Users\kocak\OneDrive\Masaüstü\Yeni klasör\globalterrorismdb_0718dist.csv', encoding='latin1')
df
# Out:
# C:\Users\kocak\AppData\Local\Temp\ipykernel_24744\3722044500.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'c:\Users\kocak\OneDrive\Masaüstü\Yeni klasör\globalterrorismdb_0718dist.csv', encoding='latin1')
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ','_').str.replace('-','_')

# %%
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# gsubname3           181671
# weapsubtype4        181621
# weapsubtype4_txt    181621
# weaptype4_txt       181618
# weaptype4           181618
# claimmode3          181558
# claimmode3_txt      181558
# gsubname2           181531
# claim3              181373
# guncertain3         181371
# dtype: int64

# %%
null_ratio = df.isnull().mean()
df = df.loc[:, null_ratio < 0.6]

# %%
df['nkill'] = pd.to_numeric(df['nkill'],errors='coerce').fillna(0)
df['nwound'] = pd.to_numeric(df['nwound'],errors='coerce').fillna(0)
# Out:
# C:\Users\kocak\AppData\Local\Temp\ipykernel_24744\580060014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nkill'] = pd.to_numeric(df['nkill'],errors='coerce').fillna(0)
# C:\Users\kocak\AppData\Local\Temp\ipykernel_24744\580060014.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nwound'] = pd.to_numeric(df['nwound'],errors='coerce').fillna(0)

# %%
df.loc[:, 'nkill'] = pd.to_numeric(df['nkill'], errors='coerce').fillna(0)
df.loc[:, 'nwound'] = pd.to_numeric(df['nwound'], errors='coerce').fillna(0)

# %%
for col in ['city','provstate','region_txt','country_txt']:
    if col in df.columns:
        df[col] = df[col].fillna('Unknown')
# Out:
# C:\Users\kocak\AppData\Local\Temp\ipykernel_24744\3583617354.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].fillna('Unknown')

# %%
df['imonth'] = df['imonth'].replace(0,1)
df['iday'] = df['iday'].replace(0,1)

df['date'] = pd.to_datetime(df[['iyear','imonth','iday']],errors='coerce')
# Out:
# C:\Users\kocak\AppData\Local\Temp\ipykernel_24744\3687019547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['imonth'] = df['imonth'].replace(0,1)
# C:\Users\kocak\AppData\Local\Temp\ipykernel_24744\3687019547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['iday'] = df['iday'].replace(0,1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
# ...
